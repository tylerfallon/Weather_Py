# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(-90.000,90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

import config

# Import the OpenWeatherMap's API key
from config import OpenWeather_API_KEY

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | sayyan
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | san ignacio
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | taoudenni
# Processing Record 11 of Set 1 | namibe
# Processing Record 12 of Set 1 | kibaya
# Processing Record 13 of Set 1 | namwala
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | tessalit
# Processing Record 16 of Set 1 | mogadouro
# Processing Record 17 of Set 1 | bokoro
# Processing Record 18 of Set 1 | boca do acre
# Processing Record 19 of Set 1 | menongue
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | malanje
# Processing Record 22 of Set 1 | narsaq
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | santa cruz de la palma
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | yar-sale
# Processing Record 27 of Set 1 | keti bandar
# Processing Record 28 of Set 1 | sadiqabad
# Processing Record 29 of Set 1 | kumylzhenskaya
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | sechura
# Processing Record 34 of Set 1 | umm lajj
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | inta
# Processing Record 37 of Set 1 | cayenne
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | doba
# Processing Record 42 of Set 1 | poshekhonye
# Processing Record 43 of Set 1 | concepcion de guasistagua
# Processing Record 44 of Set 1 | tornio
# Processing Record 45 of Set 1 | oksfjord
# Processing Record 46 of Set 1 | kilindoni
# Processing Record 47 of Set 1 | viedma
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | ust-tsilma
# Processing Record 1 of Set 2 | urumqi
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | simnas
# Processing Record 4 of Set 2 | maldonado
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | codrington
# Processing Record 11 of Set 2 | banda aceh
# Processing Record 12 of Set 2 | buchanan
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | cabedelo
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | stavern
# Processing Record 18 of Set 2 | narasannapeta
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | brae
# Processing Record 21 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 2 | tartagal
# Processing Record 23 of Set 2 | tazovskiy
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 2 | khorixas
# Processing Record 27 of Set 2 | lima
# Processing Record 28 of Set 2 | salisbury
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | ushtobe
# Processing Record 31 of Set 2 | bubaque
# Processing Record 32 of Set 2 | chicama
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | olinda
# Processing Record 36 of Set 2 | sakakah
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | trapani
# Processing Record 40 of Set 2 | aksarka
# Processing Record 41 of Set 2 | nouadhibou
# Processing Record 42 of Set 2 | saint-augustin
# Processing Record 43 of Set 2 | sangueya
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | otradinskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | at-bashi
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | oussouye
# Processing Record 50 of Set 2 | carutapera
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 3 | sur
# Processing Record 4 of Set 3 | touros
# Processing Record 5 of Set 3 | sorland
# Processing Record 6 of Set 3 | saint-paul
# Processing Record 7 of Set 3 | velingara
# Processing Record 8 of Set 3 | digha
# Processing Record 9 of Set 3 | kirya
# Processing Record 10 of Set 3 | faya
# Processing Record 11 of Set 3 | praia da vitoria
# Processing Record 12 of Set 3 | bilma
# Processing Record 13 of Set 3 | paso de carrasco
# Processing Record 14 of Set 3 | raga
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | estelle
# Processing Record 17 of Set 3 | gat
# Processing Record 18 of Set 3 | colgong
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | cumana
# Processing Record 21 of Set 3 | kant
# Processing Record 22 of Set 3 | tukrah
# Processing Record 23 of Set 3 | sao jose da coroa grande
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | le port
# Processing Record 27 of Set 3 | ouadda
# Processing Record 28 of Set 3 | garissa
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | manyana
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | denia
# Processing Record 33 of Set 3 | mao
# Processing Record 34 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 3 | skjervoy
# Processing Record 36 of Set 3 | kapoeta
# Processing Record 37 of Set 3 | kashi
# Processing Record 38 of Set 3 | karachev
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | san carlos
# Processing Record 41 of Set 3 | necochea
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | yelan
# Processing Record 45 of Set 3 | lemesos
# City not found. Skipping...
# Processing Record 46 of Set 3 | areosa
# Processing Record 47 of Set 3 | villa bruzual
# Processing Record 48 of Set 3 | birecik
# Processing Record 49 of Set 3 | tortoli
# Processing Record 50 of Set 3 | itarema
# Processing Record 1 of Set 4 | igarka
# Processing Record 2 of Set 4 | paragominas
# Processing Record 3 of Set 4 | nueva italia
# Processing Record 4 of Set 4 | kudahuvadhoo
# Processing Record 5 of Set 4 | yenotayevka
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | cap malheureux
# Processing Record 8 of Set 4 | fougamou
# Processing Record 9 of Set 4 | port blair
# Processing Record 10 of Set 4 | mecca
# Processing Record 11 of Set 4 | kenitra
# Processing Record 12 of Set 4 | floro
# Processing Record 13 of Set 4 | aktash
# Processing Record 14 of Set 4 | asfi
# Processing Record 15 of Set 4 | acarau
# Processing Record 16 of Set 4 | abbeville
# Processing Record 17 of Set 4 | quebo
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | san andres
# Processing Record 21 of Set 4 | nsanje
# Processing Record 22 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 4 | ponta delgada
# Processing Record 25 of Set 4 | trollhattan
# Processing Record 26 of Set 4 | belmonte
# Processing Record 27 of Set 4 | zorritos
# Processing Record 28 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 4 | malakisi
# City not found. Skipping...
# Processing Record 30 of Set 4 | stornoway
# Processing Record 31 of Set 4 | matay
# Processing Record 32 of Set 4 | ordzhonikidze
# Processing Record 33 of Set 4 | stolin
# Processing Record 34 of Set 4 | akhtubinsk
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | ayorou
# Processing Record 37 of Set 4 | nara
# Processing Record 38 of Set 4 | halifax
# Processing Record 39 of Set 4 | lixourion
# Processing Record 40 of Set 4 | saint-georges
# Processing Record 41 of Set 4 | kuryk
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 4 | najran
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | atar
# Processing Record 50 of Set 4 | oranjemund
# Processing Record 1 of Set 5 | mana
# Processing Record 2 of Set 5 | beirut
# Processing Record 3 of Set 5 | segezha
# Processing Record 4 of Set 5 | khandbari
# Processing Record 5 of Set 5 | ormara
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | castro
# Processing Record 8 of Set 5 | altagracia de orituco
# Processing Record 9 of Set 5 | alta floresta
# Processing Record 10 of Set 5 | fort thomas
# Processing Record 11 of Set 5 | hope mills
# Processing Record 12 of Set 5 | sinnamary
# Processing Record 13 of Set 5 | camacha
# Processing Record 14 of Set 5 | itaituba
# Processing Record 15 of Set 5 | karakol
# Processing Record 16 of Set 5 | araouane
# Processing Record 17 of Set 5 | bembereke
# Processing Record 18 of Set 5 | torbay
# Processing Record 19 of Set 5 | santarem
# Processing Record 20 of Set 5 | tashtyp
# Processing Record 21 of Set 5 | bay roberts
# Processing Record 22 of Set 5 | bonito
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | saryozek
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | svetlyy
# Processing Record 27 of Set 5 | ostersund
# Processing Record 28 of Set 5 | ciocile
# Processing Record 29 of Set 5 | ati
# Processing Record 30 of Set 5 | dunmore town
# Processing Record 31 of Set 5 | panorama
# Processing Record 32 of Set 5 | gamba
# Processing Record 33 of Set 5 | mathathane
# Processing Record 34 of Set 5 | nador
# Processing Record 35 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 5 | temir
# Processing Record 37 of Set 5 | arauca
# Processing Record 38 of Set 5 | mutoko
# Processing Record 39 of Set 5 | usinsk
# Processing Record 40 of Set 5 | muros
# Processing Record 41 of Set 5 | tombouctou
# Processing Record 42 of Set 5 | caxito
# Processing Record 43 of Set 5 | ambatolampy
# Processing Record 44 of Set 5 | krasnotorka
# Processing Record 45 of Set 5 | antofagasta
# Processing Record 46 of Set 5 | pout
# Processing Record 47 of Set 5 | cluses
# Processing Record 48 of Set 5 | ugoofaaru
# Processing Record 49 of Set 5 | north myrtle beach
# Processing Record 50 of Set 5 | khairpur
# Processing Record 1 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 6 | khor
# Processing Record 3 of Set 6 | ibra
# Processing Record 4 of Set 6 | olafsvik
# Processing Record 5 of Set 6 | morondava
# Processing Record 6 of Set 6 | teguldet
# Processing Record 7 of Set 6 | lindi
# Processing Record 8 of Set 6 | micheweni
# Processing Record 9 of Set 6 | cherdyn
# Processing Record 10 of Set 6 | yayva
# Processing Record 11 of Set 6 | kasongo-lunda
# Processing Record 12 of Set 6 | baherden
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | torquay
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 6 | westport
# Processing Record 19 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 6 | wajir
# Processing Record 21 of Set 6 | port-gentil
# Processing Record 22 of Set 6 | aswan
# Processing Record 23 of Set 6 | stromness
# Processing Record 24 of Set 6 | nokia
# Processing Record 25 of Set 6 | saint-francois
# Processing Record 26 of Set 6 | minna
# Processing Record 27 of Set 6 | pakwach
# City not found. Skipping...
# Processing Record 28 of Set 6 | bereda
# Processing Record 29 of Set 6 | puerto carreno
# Processing Record 30 of Set 6 | makurdi
# Processing Record 31 of Set 6 | soller
# Processing Record 32 of Set 6 | numan
# Processing Record 33 of Set 6 | ostrovnoy
# Processing Record 34 of Set 6 | toktogul
# Processing Record 35 of Set 6 | rock hill
# Processing Record 36 of Set 6 | nizwa
# Processing Record 37 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 6 | iranduba
# Processing Record 39 of Set 6 | harrisonburg
# Processing Record 40 of Set 6 | great yarmouth
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | urucui
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | aguimes
# Processing Record 45 of Set 6 | sembe
# Processing Record 46 of Set 6 | atarra
# Processing Record 47 of Set 6 | adrar
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | largo
# Processing Record 50 of Set 6 | huambo
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | urucurituba
# Processing Record 3 of Set 7 | ippy
# Processing Record 4 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 7 | lokoja
# Processing Record 6 of Set 7 | luanda
# Processing Record 7 of Set 7 | ocean city
# Processing Record 8 of Set 7 | barcelos
# Processing Record 9 of Set 7 | jalingo
# Processing Record 10 of Set 7 | qaqortoq
# Processing Record 11 of Set 7 | quimper
# Processing Record 12 of Set 7 | chabahar
# Processing Record 13 of Set 7 | diffa
# Processing Record 14 of Set 7 | liniere
# City not found. Skipping...
# Processing Record 15 of Set 7 | yining
# Processing Record 16 of Set 7 | laguna
# Processing Record 17 of Set 7 | impfondo
# Processing Record 18 of Set 7 | alpena
# Processing Record 19 of Set 7 | nyimba
# Processing Record 20 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 21 of Set 7 | moose factory
# Processing Record 22 of Set 7 | axim
# Processing Record 23 of Set 7 | jalalpur pirwala
# Processing Record 24 of Set 7 | weiden
# Processing Record 25 of Set 7 | vincennes
# Processing Record 26 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 7 | blagoyevo
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | veraval
# Processing Record 30 of Set 7 | ambilobe
# Processing Record 31 of Set 7 | mitsamiouli
# Processing Record 32 of Set 7 | wawa
# Processing Record 33 of Set 7 | paita
# Processing Record 34 of Set 7 | harlingen
# Processing Record 35 of Set 7 | buraydah
# Processing Record 36 of Set 7 | mongo
# Processing Record 37 of Set 7 | carballo
# Processing Record 38 of Set 7 | takoradi
# Processing Record 39 of Set 7 | the valley
# Processing Record 40 of Set 7 | oum hadjer
# Processing Record 41 of Set 7 | jalu
# Processing Record 42 of Set 7 | kautokeino
# Processing Record 43 of Set 7 | san isidro
# Processing Record 44 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 7 | urla
# Processing Record 46 of Set 7 | tiangua
# Processing Record 47 of Set 7 | henties bay
# Processing Record 48 of Set 7 | vila franca do campo
# Processing Record 49 of Set 7 | garachine
# Processing Record 50 of Set 7 | tambacounda
# Processing Record 1 of Set 8 | nalut
# Processing Record 2 of Set 8 | nargana
# Processing Record 3 of Set 8 | plettenberg bay
# Processing Record 4 of Set 8 | effium
# Processing Record 5 of Set 8 | maridi
# Processing Record 6 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 8 | dorado
# Processing Record 8 of Set 8 | belousovka
# Processing Record 9 of Set 8 | la primavera
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | orangeville
# Processing Record 12 of Set 8 | comodoro rivadavia
# Processing Record 13 of Set 8 | trincomalee
# Processing Record 14 of Set 8 | cap-aux-meules
# Processing Record 15 of Set 8 | vestmannaeyjar
# Processing Record 16 of Set 8 | taylorville
# Processing Record 17 of Set 8 | abay
# Processing Record 18 of Set 8 | saint-pierre
# Processing Record 19 of Set 8 | kinsale
# Processing Record 20 of Set 8 | burica
# City not found. Skipping...
# Processing Record 21 of Set 8 | senanga
# Processing Record 22 of Set 8 | puerto colombia
# Processing Record 23 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 8 | villaviciosa
# Processing Record 25 of Set 8 | zhezkazgan
# Processing Record 26 of Set 8 | manavalakurichi
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | ambovombe
# Processing Record 29 of Set 8 | virginia beach
# Processing Record 30 of Set 8 | senekal
# Processing Record 31 of Set 8 | montague
# Processing Record 32 of Set 8 | port-cartier
# Processing Record 33 of Set 8 | ballina
# Processing Record 34 of Set 8 | aksu
# Processing Record 35 of Set 8 | pailitas
# Processing Record 36 of Set 8 | frydlant nad ostravici
# Processing Record 37 of Set 8 | caibarien
# Processing Record 38 of Set 8 | padang
# Processing Record 39 of Set 8 | dhidhdhoo
# Processing Record 40 of Set 8 | sipe sipe
# Processing Record 41 of Set 8 | bardiyah
# Processing Record 42 of Set 8 | xai-xai
# Processing Record 43 of Set 8 | mocuba
# Processing Record 44 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 8 | nikel
# Processing Record 46 of Set 8 | grand gaube
# Processing Record 47 of Set 8 | santana do livramento
# Processing Record 48 of Set 8 | san carlos de bariloche
# Processing Record 49 of Set 8 | velsk
# Processing Record 50 of Set 8 | les cayes
# Processing Record 1 of Set 9 | magaria
# Processing Record 2 of Set 9 | arlit
# Processing Record 3 of Set 9 | chiredzi
# Processing Record 4 of Set 9 | los llanos de aridane
# Processing Record 5 of Set 9 | warka
# Processing Record 6 of Set 9 | florianopolis
# Processing Record 7 of Set 9 | sao filipe
# Processing Record 8 of Set 9 | sivaganga
# Processing Record 9 of Set 9 | kochki
# Processing Record 10 of Set 9 | general roca
# Processing Record 11 of Set 9 | corinto
# Processing Record 12 of Set 9 | tiznit
# Processing Record 13 of Set 9 | hofn
# Processing Record 14 of Set 9 | porbandar
# Processing Record 15 of Set 9 | peniche
# Processing Record 16 of Set 9 | perdika
# Processing Record 17 of Set 9 | leh
# Processing Record 18 of Set 9 | bud
# Processing Record 19 of Set 9 | san cristobal
# Processing Record 20 of Set 9 | thessalon
# Processing Record 21 of Set 9 | chardara
# Processing Record 22 of Set 9 | koslan
# Processing Record 23 of Set 9 | dharchula
# Processing Record 24 of Set 9 | edd
# Processing Record 25 of Set 9 | mount darwin
# Processing Record 26 of Set 9 | awjilah
# Processing Record 27 of Set 9 | mugla
# Processing Record 28 of Set 9 | manono
# Processing Record 29 of Set 9 | marquette
# Processing Record 30 of Set 9 | riviere-au-renard
# Processing Record 31 of Set 9 | victoria
# Processing Record 32 of Set 9 | oeiras
# Processing Record 33 of Set 9 | asyut
# Processing Record 34 of Set 9 | lancaster
# Processing Record 35 of Set 9 | vagay
# Processing Record 36 of Set 9 | kidal
# Processing Record 37 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 9 | tefe
# Processing Record 39 of Set 9 | abha
# Processing Record 40 of Set 9 | marsa matruh
# Processing Record 41 of Set 9 | severnoye
# Processing Record 42 of Set 9 | esil
# Processing Record 43 of Set 9 | ullapool
# Processing Record 44 of Set 9 | rawson
# Processing Record 45 of Set 9 | fredericton
# Processing Record 46 of Set 9 | lehututu
# Processing Record 47 of Set 9 | domoni
# Processing Record 48 of Set 9 | grindavik
# Processing Record 49 of Set 9 | bom jesus
# Processing Record 50 of Set 9 | zaozerne
# Processing Record 1 of Set 10 | jacareacanga
# Processing Record 2 of Set 10 | tyup
# Processing Record 3 of Set 10 | barranca
# Processing Record 4 of Set 10 | turkan
# Processing Record 5 of Set 10 | santiago del estero
# Processing Record 6 of Set 10 | zabol
# Processing Record 7 of Set 10 | ornskoldsvik
# Processing Record 8 of Set 10 | wajid
# Processing Record 9 of Set 10 | shelabolikha
# Processing Record 10 of Set 10 | soyo
# Processing Record 11 of Set 10 | chulym
# Processing Record 12 of Set 10 | durres
# Processing Record 13 of Set 10 | andenes
# Processing Record 14 of Set 10 | moyale
# Processing Record 15 of Set 10 | chebsara
# Processing Record 16 of Set 10 | saint leonard
# Processing Record 17 of Set 10 | arroio grande
# Processing Record 18 of Set 10 | kusk
# City not found. Skipping...
# Processing Record 19 of Set 10 | itaqui
# Processing Record 20 of Set 10 | gazli
# Processing Record 21 of Set 10 | mehamn
# Processing Record 22 of Set 10 | mwene-ditu
# Processing Record 23 of Set 10 | briceno
# Processing Record 24 of Set 10 | glushkovo
# Processing Record 25 of Set 10 | giyon
# Processing Record 26 of Set 10 | barinas
# Processing Record 27 of Set 10 | el cobre
# Processing Record 28 of Set 10 | durusu
# Processing Record 29 of Set 10 | binga
# Processing Record 30 of Set 10 | cockburn town
# Processing Record 31 of Set 10 | talnakh
# Processing Record 32 of Set 10 | maceio
# Processing Record 33 of Set 10 | concarneau
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | perevolotskiy
# Processing Record 36 of Set 10 | manali
# Processing Record 37 of Set 10 | manaure
# Processing Record 38 of Set 10 | oistins
# Processing Record 39 of Set 10 | abu dhabi
# Processing Record 40 of Set 10 | maragogi
# Processing Record 41 of Set 10 | dedougou
# Processing Record 42 of Set 10 | abu zabad
# Processing Record 43 of Set 10 | beitbridge
# Processing Record 44 of Set 10 | molchanovo
# Processing Record 45 of Set 10 | pitimbu
# Processing Record 46 of Set 10 | susehri
# Processing Record 47 of Set 10 | guiratinga
# Processing Record 48 of Set 10 | puerto narino
# Processing Record 49 of Set 10 | sokolac
# Processing Record 50 of Set 10 | havoysund
# Processing Record 1 of Set 11 | breytovo
# Processing Record 2 of Set 11 | mikhaylovka
# Processing Record 3 of Set 11 | vallenar
# Processing Record 4 of Set 11 | tomakivka
# Processing Record 5 of Set 11 | eskisehir
# Processing Record 6 of Set 11 | pangnirtung
# Processing Record 7 of Set 11 | santa marta
# Processing Record 8 of Set 11 | tabou
# Processing Record 9 of Set 11 | acari
# Processing Record 10 of Set 11 | kemijarvi
# Processing Record 11 of Set 11 | belsand
# Processing Record 12 of Set 11 | franklin park
# Processing Record 13 of Set 11 | benghazi
# Processing Record 14 of Set 11 | paamiut
# Processing Record 15 of Set 11 | la tour-de-peilz
# Processing Record 16 of Set 11 | lubango
# Processing Record 17 of Set 11 | rocha
# Processing Record 18 of Set 11 | mahalapye
# Processing Record 19 of Set 11 | mokrousovo
# Processing Record 20 of Set 11 | rundu
# Processing Record 21 of Set 11 | kurchum
# Processing Record 22 of Set 11 | tshela
# Processing Record 23 of Set 11 | boa vista
# Processing Record 24 of Set 11 | altay
# Processing Record 25 of Set 11 | conde
# Processing Record 26 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 11 | gaya
# Processing Record 28 of Set 11 | luba
# Processing Record 29 of Set 11 | mogadishu
# Processing Record 30 of Set 11 | susurluk
# Processing Record 31 of Set 11 | salvador
# Processing Record 32 of Set 11 | dezful
# Processing Record 33 of Set 11 | anloga
# Processing Record 34 of Set 11 | ljungby
# Processing Record 35 of Set 11 | banyo
# Processing Record 36 of Set 11 | storslett
# Processing Record 37 of Set 11 | havelock
# Processing Record 38 of Set 11 | dothan
# Processing Record 39 of Set 11 | colares
# Processing Record 40 of Set 11 | bosobolo
# Processing Record 41 of Set 11 | urengoy
# Processing Record 42 of Set 11 | voznesenye
# Processing Record 43 of Set 11 | lokosovo
# Processing Record 44 of Set 11 | punta cardon
# Processing Record 45 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 11 | santa cruz
# Processing Record 47 of Set 11 | mercedes
# Processing Record 48 of Set 11 | vavuniya
# Processing Record 49 of Set 11 | khersonisos
# City not found. Skipping...
# Processing Record 50 of Set 11 | iserlohn
# Processing Record 1 of Set 12 | pennagaram
# Processing Record 2 of Set 12 | sharjah
# Processing Record 3 of Set 12 | la macarena
# Processing Record 4 of Set 12 | portovelo
# Processing Record 5 of Set 12 | pangody
# Processing Record 6 of Set 12 | pashiya
# Processing Record 7 of Set 12 | bocas del toro
# Processing Record 8 of Set 12 | birjand
# Processing Record 9 of Set 12 | san vicente de canete
# Processing Record 10 of Set 12 | maiduguri
# Processing Record 11 of Set 12 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 12 of Set 12 | mafinga
# Processing Record 13 of Set 12 | ust-ishim
# Processing Record 14 of Set 12 | turayf
# Processing Record 15 of Set 12 | teguise
# Processing Record 16 of Set 12 | manicore
# Processing Record 17 of Set 12 | saint anthony
# Processing Record 18 of Set 12 | booue
# Processing Record 19 of Set 12 | sovetskiy
# Processing Record 20 of Set 12 | surab
# Processing Record 21 of Set 12 | yakhroma
# Processing Record 22 of Set 12 | kulhudhuffushi
# Processing Record 23 of Set 12 | sibirskiy
# Processing Record 24 of Set 12 | calama
# Processing Record 25 of Set 12 | rabo de peixe
# Processing Record 26 of Set 12 | hambantota
# Processing Record 27 of Set 12 | warren
# Processing Record 28 of Set 12 | paracuru
# Processing Record 29 of Set 12 | ouango
# Processing Record 30 of Set 12 | mahajanga
# Processing Record 31 of Set 12 | littleton
# Processing Record 32 of Set 12 | oliveira dos brejinhos
# Processing Record 33 of Set 12 | niquelandia
# Processing Record 34 of Set 12 | nisia floresta
# Processing Record 35 of Set 12 | changji
# Processing Record 36 of Set 12 | niksar
# Processing Record 37 of Set 12 | cururupu
# Processing Record 38 of Set 12 | piombino
# Processing Record 39 of Set 12 | llangefni
# Processing Record 40 of Set 12 | sergeyevka
# Processing Record 41 of Set 12 | morant bay
# Processing Record 42 of Set 12 | sikonge
# Processing Record 43 of Set 12 | santa maria
# Processing Record 44 of Set 12 | krasnoselkup
# Processing Record 45 of Set 12 | marigot
# Processing Record 46 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 47 of Set 12 | kutum
# Processing Record 48 of Set 12 | igrim
# Processing Record 49 of Set 12 | aubenas
# Processing Record 50 of Set 12 | mineiros
# Processing Record 1 of Set 13 | ajdabiya
# Processing Record 2 of Set 13 | pointe-noire
# Processing Record 3 of Set 13 | rimini
# Processing Record 4 of Set 13 | zheleznodorozhnyy
# Processing Record 5 of Set 13 | djambala
# Processing Record 6 of Set 13 | zonguldak
# Processing Record 7 of Set 13 | birin
# Processing Record 8 of Set 13 | ribeira brava
# Processing Record 9 of Set 13 | gasa
# Processing Record 10 of Set 13 | balvi
# Processing Record 11 of Set 13 | inirida
# Processing Record 12 of Set 13 | barentu
# Processing Record 13 of Set 13 | simitli
# Processing Record 14 of Set 13 | geraldton
# Processing Record 15 of Set 13 | mattru
# Processing Record 16 of Set 13 | mulchen
# Processing Record 17 of Set 13 | nanga eboko
# Processing Record 18 of Set 13 | riacho de santana
# Processing Record 19 of Set 13 | ancud
# Processing Record 20 of Set 13 | chongwe
# Processing Record 21 of Set 13 | akhnur
# Processing Record 22 of Set 13 | saint-denis
# Processing Record 23 of Set 13 | novopokrovka
# Processing Record 24 of Set 13 | chirongui
# Processing Record 25 of Set 13 | kirkland lake
# Processing Record 26 of Set 13 | gornopravdinsk
# Processing Record 27 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 13 | toropets
# Processing Record 29 of Set 13 | george
# Processing Record 30 of Set 13 | orapa
# Processing Record 31 of Set 13 | pachino
# Processing Record 32 of Set 13 | raudeberg
# Processing Record 33 of Set 13 | bull savanna
# Processing Record 34 of Set 13 | new baltimore
# Processing Record 35 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 36 of Set 13 | ofaqim
# Processing Record 37 of Set 13 | metkovic
# Processing Record 38 of Set 13 | vsevolozhsk
# Processing Record 39 of Set 13 | belyy yar
# Processing Record 40 of Set 13 | kralendijk
# Processing Record 41 of Set 13 | port hawkesbury
# Processing Record 42 of Set 13 | ansermanuevo
# Processing Record 43 of Set 13 | bakel
# Processing Record 44 of Set 13 | strezhevoy
# Processing Record 45 of Set 13 | kuliyapitiya
# Processing Record 46 of Set 13 | mutis
# Processing Record 47 of Set 13 | abu kamal
# Processing Record 48 of Set 13 | agsu
# City not found. Skipping...
# Processing Record 49 of Set 13 | korla
# Processing Record 50 of Set 13 | kribi
# Processing Record 1 of Set 14 | duz
# City not found. Skipping...
# Processing Record 2 of Set 14 | tsumeb
# Processing Record 3 of Set 14 | zuwarah
# Processing Record 4 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 14 | lasa
# Processing Record 6 of Set 14 | baracoa
# Processing Record 7 of Set 14 | totness
# Processing Record 8 of Set 14 | eichstatt
# Processing Record 9 of Set 14 | kristiansund
# Processing Record 10 of Set 14 | hattiesburg
# Processing Record 11 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 14 | baghdad
# Processing Record 13 of Set 14 | shediac
# Processing Record 14 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 14 | sambava
# Processing Record 16 of Set 14 | bonthe
# Processing Record 17 of Set 14 | grand baie
# Processing Record 18 of Set 14 | parana
# Processing Record 19 of Set 14 | bojnurd
# Processing Record 20 of Set 14 | am timan
# Processing Record 21 of Set 14 | vicuna
# Processing Record 22 of Set 14 | aden
# Processing Record 23 of Set 14 | qobustan
# Processing Record 24 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 25 of Set 14 | jarjis
# City not found. Skipping...
# Processing Record 26 of Set 14 | maniitsoq
# Processing Record 27 of Set 14 | keffi
# Processing Record 28 of Set 14 | pudozh
# Processing Record 29 of Set 14 | taybad
# Processing Record 30 of Set 14 | benjamin constant
# Processing Record 31 of Set 14 | batticaloa
# Processing Record 32 of Set 14 | pucallpa
# Processing Record 33 of Set 14 | jardim
# Processing Record 34 of Set 14 | puerto quijarro
# Processing Record 35 of Set 14 | douglas
# Processing Record 36 of Set 14 | kiel
# Processing Record 37 of Set 14 | amposta
# Processing Record 38 of Set 14 | garm
# City not found. Skipping...
# Processing Record 39 of Set 14 | riyadh
# Processing Record 40 of Set 14 | varnamo
# Processing Record 41 of Set 14 | warmbad
# Processing Record 42 of Set 14 | otjimbingwe
# Processing Record 43 of Set 14 | malakal
# Processing Record 44 of Set 14 | zwedru
# Processing Record 45 of Set 14 | san ramon
# Processing Record 46 of Set 14 | maarianhamina
# Processing Record 47 of Set 14 | okha
# Processing Record 48 of Set 14 | dabola
# Processing Record 49 of Set 14 | manacapuru
# Processing Record 50 of Set 14 | andreapol
# Processing Record 1 of Set 15 | roald
# Processing Record 2 of Set 15 | izhma
# Processing Record 3 of Set 15 | sohag
# Processing Record 4 of Set 15 | crotone
# Processing Record 5 of Set 15 | severnyy-kospashskiy
# Processing Record 6 of Set 15 | umm kaddadah
# Processing Record 7 of Set 15 | chongoyape
# Processing Record 8 of Set 15 | quatre cocos
# Processing Record 9 of Set 15 | talara
# Processing Record 10 of Set 15 | rorvik
# Processing Record 11 of Set 15 | udimskiy
# Processing Record 12 of Set 15 | lerwick
# Processing Record 13 of Set 15 | bonoua
# Processing Record 14 of Set 15 | dire
# Processing Record 15 of Set 15 | mungaoli
# Processing Record 16 of Set 15 | shubarshi
# Processing Record 17 of Set 15 | belaya kholunitsa
# Processing Record 18 of Set 15 | marzuq
# Processing Record 19 of Set 15 | norrtalje
# Processing Record 20 of Set 15 | hopelchen
# Processing Record 21 of Set 15 | yeghegnut
# Processing Record 22 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 15 | zenzeli
# Processing Record 24 of Set 15 | pickerington
# Processing Record 25 of Set 15 | pontes e lacerda
# Processing Record 26 of Set 15 | mount vernon
# Processing Record 27 of Set 15 | ouro preto
# Processing Record 28 of Set 15 | uporovo
# Processing Record 29 of Set 15 | mizdah
# Processing Record 30 of Set 15 | mitu
# Processing Record 31 of Set 15 | mahon
# Processing Record 32 of Set 15 | abalak
# Processing Record 33 of Set 15 | talcahuano
# Processing Record 34 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 35 of Set 15 | saint-joseph
# Processing Record 36 of Set 15 | zaysan
# Processing Record 37 of Set 15 | wilmington
# Processing Record 38 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | san lawrenz
# Processing Record 40 of Set 15 | kagadi
# Processing Record 41 of Set 15 | lakselv
# Processing Record 42 of Set 15 | ntcheu
# Processing Record 43 of Set 15 | havre-saint-pierre
# Processing Record 44 of Set 15 | vavoua
# Processing Record 45 of Set 15 | oktyabrskiy
# Processing Record 46 of Set 15 | dortmund
# Processing Record 47 of Set 15 | bo
# City not found. Skipping...
# Processing Record 48 of Set 15 | sept-iles
# Processing Record 49 of Set 15 | kassala
# Processing Record 50 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 16 | calvinia
# Processing Record 2 of Set 16 | mingaora
# Processing Record 3 of Set 16 | uruzgan
# Processing Record 4 of Set 16 | kangaba
# Processing Record 5 of Set 16 | francisco sa
# Processing Record 6 of Set 16 | faxinal
# Processing Record 7 of Set 16 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas -53.1500  -70.9167     53.71        50          75
# 1           Sayyan  15.1718   44.3244     55.63        21           4
# 2            Vardo  70.3705   31.1107     30.18        80         100
# 3      San Ignacio  17.1561  -89.0714     73.54       100          75
# 4        Busselton -33.6500  115.3333     64.80        50          77
# 5   Port Elizabeth -33.9180   25.5701     63.32        80          20
# 6      Port Alfred -33.5906   26.8910     60.19        93         100
# 7  Arraial Do Cabo -22.9661  -42.0278     69.12        66           4
# 8        Taoudenni  22.6783   -3.9836     71.01        14          85
# 9           Namibe -15.1961   12.1522     72.46        76          98
#
#    Wind Speed Country          Current Description
# 0       29.93      CL  light intensity shower rain
# 1        5.06      YE                    clear sky
# 2       25.32      NO              overcast clouds
# 3        4.61      BZ                broken clouds
# 4       15.70      AU                broken clouds
# 5       13.80      ZA                   light rain
# 6        5.01      ZA              overcast clouds
# 7        2.35      BR                    clear sky
# 8        4.05      ML              overcast clouds
# 9        5.59      AO              overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     53.71        50          75
# 1           Sayyan      YE  15.1718   44.3244     55.63        21           4
# 2            Vardo      NO  70.3705   31.1107     30.18        80         100
# 3      San Ignacio      BZ  17.1561  -89.0714     73.54       100          75
# 4        Busselton      AU -33.6500  115.3333     64.80        50          77
# 5   Port Elizabeth      ZA -33.9180   25.5701     63.32        80          20
# 6      Port Alfred      ZA -33.5906   26.8910     60.19        93         100
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     69.12        66           4
# 8        Taoudenni      ML  22.6783   -3.9836     71.01        14          85
# 9           Namibe      AO -15.1961   12.1522     72.46        76          98
#
#    Wind Speed          Current Description
# 0       29.93  light intensity shower rain
# 1        5.06                    clear sky
# 2       25.32              overcast clouds
# 3        4.61                broken clouds
# 4       15.70                broken clouds
# 5       13.80                   light rain
# 6        5.01              overcast clouds
# 7        2.35                    clear sky
# 8        4.05              overcast clouds
# 9        5.59              overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 699 non-null    object
#  1   Country              699 non-null    object
#  2   Lat                  699 non-null    float64
#  3   Lng                  699 non-null    float64
#  4   Max Temp             699 non-null    float64
#  5   Humidity             699 non-null    int64
#  6   Cloudiness           699 non-null    int64
#  7   Wind Speed           699 non-null    float64
#  8   Current Description  699 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 49.3+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_name = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_name)
